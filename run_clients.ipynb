# %%
import schedule
import time
import functools
import threading
import os
import yaml

# %%
BASE_DIR = os.path.dirname(os.path.abspath("."))
YAML_CLIENTS = os.path.join(BASE_DIR, "HOTELRATES", 'clients.yml')

with open(YAML_CLIENTS, "r") as f_in:
    CLIENTS = yaml.safe_load(f_in)

# %%
for name, data_client in CLIENTS.items():
    print(data_client["key"])
# Out:
# 10vet57RQGSTB2SLOLhwJPehER9nU6gixURsYHv6NULU
# 1RdMYizuQI7Mlv_Qt2Nswvqqwk1s8xHLguVc-GTH4PVQ
